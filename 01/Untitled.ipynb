# %%
# How many measurements increase from the previous measurment?

# %%
import pandas as pd

# %%
depths = pd.read_csv('readings.csv', header=None)
depths
# Out:
#          0
# 0      122
# 1      129
# 2      116
# 3      122
# 4      135
# ...    ...
# 1995  6569
# 1996  6563
# 1997  6591
# 1998  6601
# 1999  6632
#
# [2000 rows x 1 columns]

# %%
depths_list = depths.values.tolist()
print(depths_list)
# Out:
# [[122], [129], [116], [122], [135], [148], [151], [158], [161], [179], [197], [198], [187], [210], [211], [206], [207], [210], [211], [216], [222], [224], [222], [234], [237], [238], [239], [245], [276], [262], [268], [266], [293], [291], [293], [296], [298], [291], [292], [295], [297], [298], [297], [300], [297], [309], [315], [319], [320], [319], [323], [338], [349], [351], [352], [354], [348], [366], [365], [388], [385], [379], [381], [385], [391], [392], [405], [407], [415], [427], [433], [436], [439], [444], [450], [449], [453], [457], [459], [460], [467], [471], [474], [473], [477], [487], [489], [498], [512], [516], [507], [526], [544], [560], [570], [569], [580], [590], [591], [593], [596], [597], [598], [604], [599], [608], [603], [616], [649], [636], [649], [648], [653], [654], [655], [656], [664], [666], [669], [663], [661], [682], [681], [685], [693], [701], [727], [706], [704], [705], [706], [711], [716], [711], [721], [728], [724], [734], [733], [737], [736], [742], [74
# ...

# %%
# Count
increase_count = 0

# zip the two lists together so you compare list 1 to list 2 + 1 index position forward
for x, y in zip(depths_list, depths_list[1:]):
    if x < y:
        increase_count +=1 # add to count if it's higher
        print(x,y) # check work to see if it's comparing correctly
    else: 
        pass
# Out:
# [122] [129]
# [116] [122]
# [122] [135]
# [135] [148]
# [148] [151]
# [151] [158]
# [158] [161]
# [161] [179]
# [179] [197]
# [197] [198]
# [187] [210]
# [210] [211]
# [206] [207]
# [207] [210]
# [210] [211]
# [211] [216]
# [216] [222]
# [222] [224]
# [222] [234]
# [234] [237]
# [237] [238]
# [238] [239]
# [239] [245]
# [245] [276]
# [262] [268]
# [266] [293]
# [291] [293]
# [293] [296]
# [296] [298]
# [291] [292]
# [292] [295]
# [295] [297]
# [297] [298]
# [297] [300]
# [297] [309]
# [309] [315]
# [315] [319]
# [319] [320]
# [319] [323]
# [323] [338]
# [338] [349]
# [349] [351]
# [351] [352]
# [352] [354]
# [348] [366]
# [365] [388]
# [379] [381]
# [381] [385]
# [385] [391]
# [391] [392]
# [392] [405]
# [405] [407]
# [407] [415]
# [415] [427]
# [427] [433]
# [433] [436]
# [436] [439]
# [439] [444]
# [444] [450]
# [449] [453]
# [453] [457]
# [457] [459]
# [459] [460]
# [460] [467]
# [467] [471]
# [471] [474]
# [473] [477]
# [477] [487]
# [487] [489]
# [489] [498]
# [498] [512]
# ...

# %%
print(increase_count)
# Out:
# 1462
